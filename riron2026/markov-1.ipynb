# %%
import numpy as np
import random as rm
import sys
import matplotlib.pyplot as plt

# The statespace
states = ["Chabudai","Husuma","TV"]

transitionName = [["CC","CT","CH"],["HH","HT","HC"],["TT","TH","TC"]]
transitionMatrix = [[0.2,0.5,0.3],[0.1,0.6,0.3],[0.5,0.5,0.0]]

alist = []

def generate_sequence(days, cPos):
    # Choose the starting state
    currentPosition = cPos
    alist.append(currentPosition)
    #print("Start state: " + currentPosition)
    # Shall store the sequence of states taken. So, this only has the starting state for now.
    activityList = [currentPosition]
    i = 0
    # To calculate the probability of the activityList
    prob = 1
    while i != days:
        if currentPosition == "Chabudai":
            change = np.random.choice(transitionName[0],replace=True,p=transitionMatrix[0])
            if change == "CC":
                prob = prob * 0.2
                activityList.append("Chabudai")
                alist.append("Chabudai")
                pass
            elif change == "CT":
                prob = prob * 0.5
                currentPosition = "TV"
                activityList.append("TV")
                alist.append("TV")
            else:
                prob = prob * 0.3
                currentPosition = "Husuma"
                activityList.append("Husuma")
                alist.append("Husuma")
                
        elif currentPosition == "Husuma":
            change = np.random.choice(transitionName[1],replace=True,p=transitionMatrix[1])
            if change == "HC":
                prob = prob * 0.3
                activityList.append("Chabudai")
                alist.append("Chabudai")
                pass
            elif change == "HT":
                prob = prob * 0.6
                currentPosition = "TV"
                activityList.append("TV")
                alist.append("TV")
            else:
                prob = prob * 0.1
                currentPosition = "Husuma"
                activityList.append("Husuma")
                alist.append("Husuma")
                
        elif currentPosition == "TV":
            change = np.random.choice(transitionName[2],replace=True,p=transitionMatrix[2])
            if change == "TC":
                prob = prob * 0.0
                activityList.append("Chabudai")
                alist.append("Chabudai")
                pass
            elif change == "TH":
                prob = prob * 0.3
                currentPosition = "Husuma"
                activityList.append("Husuma")
                alist.append("Husuma")
            else:
                prob = prob * 0.5
                currentPosition = "TV"
                activityList.append("TV")
                alist.append("TV")
        i += 1  


#args = sys.argv
startPosition="TV"

LENGTH = 621
counter = 0

TV_seq = []
Chabudai_seq = []
Husuma_seq = []

for i in range(1,LENGTH,2):
    LEN = i - 1
    alist = []
    
    generate_sequence(LEN, startPosition)

    counter = counter + 1
    
    if counter % 10 == 0:
        sum = alist.count('Chabudai') + alist.count('Husuma') + alist.count('TV') 
        Chabudai_seq.append((alist.count('Chabudai'))/sum*100)
        Husuma_seq.append((alist.count('Husuma'))/sum*100)
        TV_seq.append((alist.count('TV'))/sum*100)
    
    rstring = '' 
    for i in alist:
        rstring = rstring + i[0]
    #print(rstring)

    
print(alist)    

LChabudai_seq = "".join([str(_) + "->" for _ in Chabudai_seq])
LHusuma_seq = "".join([str(_)  + "->" for _ in Husuma_seq])
LTV_seq = "".join([str(_)  + "->" for _ in TV_seq])

print(" ")
print("Cの定常確率:" + LChabudai_seq)
print(" ")
print("Hの定常確率:" + LHusuma_seq)
print(" ")
print("Tの定常確率:" + LTV_seq)
print(" ")

plt.plot(Chabudai_seq, label="teijou-kakuritsu: C")
plt.plot(Husuma_seq, label="teijou-kakuritsu: H")
plt.plot(TV_seq, label="teijou-kakuritsu: T")
plt.legend()
plt.show()
# Out:
# ['TV', 'Husuma', 'TV', 'TV', 'TV', 'Husuma', 'TV', 'Husuma', 'TV', 'TV', 'TV', 'Husuma', 'Chabudai', 'Chabudai', 'TV', 'Husuma', 'TV', 'Husuma', 'TV', 'Husuma', 'Husuma', 'TV', 'Husuma', 'TV', 'TV', 'TV', 'TV', 'Husuma', 'TV', 'Husuma', 'TV', 'Husuma', 'Husuma', 'TV', 'Husuma', 'TV', 'TV', 'TV', 'Husuma', 'Chabudai', 'Chabudai', 'TV', 'Husuma', 'Husuma', 'TV', 'TV', 'Husuma', 'TV', 'TV', 'TV', 'Husuma', 'Chabudai', 'TV', 'TV', 'TV', 'TV', 'Husuma', 'Chabudai', 'TV', 'Husuma', 'TV', 'Husuma', 'TV', 'TV', 'Husuma', 'Chabudai', 'TV', 'TV', 'TV', 'Husuma', 'TV', 'Husuma', 'TV', 'Husuma', 'TV', 'Husuma', 'Chabudai', 'Chabudai', 'Husuma', 'Chabudai', 'Chabudai', 'TV', 'Husuma', 'TV', 'Husuma', 'Chabudai', 'TV', 'TV', 'Husuma', 'Husuma', 'Chabudai', 'Chabudai', 'TV', 'TV', 'Husuma', 'TV', 'Husuma', 'TV', 'TV', 'TV', 'Husuma', 'Chabudai', 'TV', 'Husuma', 'Chabudai', 'TV', 'Husuma', 'Husuma', 'TV', 'Husuma', 'TV', 'Husuma', 'TV', 'TV', 'TV', 'Husuma', 'Chabudai', 'TV', 'TV', 'TV', 'TV', 'Husuma', 'TV', 'Husuma', 'TV', 'Husuma', 'Chabudai', 'TV', 'Husuma', 'TV', 'Husuma', 'Chabudai', 'TV', 'Husuma', 'TV', 'Husuma', 'Chabudai', 'TV', 'Husuma', 'Chabudai', 'TV', 'TV', 'TV', 'TV', 'Husuma', 'Husuma', 'TV', 'Husuma', 'Chabudai', 'Husuma', 'TV', 'Husuma', 'TV', 'TV', 'Husuma', 'Chabudai', 'TV', 'TV', 'Husuma', 'TV', 'Husuma', 'TV', 'Husuma', 'Husuma', 'Chabudai', 'TV', 'TV', 'TV', 'TV', 'TV', 'TV', 'TV', 'TV', 'Husuma', 'TV', 'Husuma', 'Husuma', 'TV', 'TV', 'TV', 'TV', 'Husuma', 'Chabudai', 'Chabudai', 'Husuma', 'TV', 'Husuma', 'Husuma', 'Husuma', 'Chabudai', 'Chabudai', 'TV', 'Husuma', 'Chabudai', 'TV', 'Husuma', 'Chabudai', 'Chabudai', 'TV', 'TV', 'Husuma', 'TV', 'TV', 'TV', 'Husuma', 'Chabudai', 'Chabudai', 'TV', 'Husuma', 'TV', 'TV', 'Husuma', 'TV', 'Husuma', 'Chabudai', 'TV', 'Husuma', 'Chabudai', 'Husuma', 'Chabudai', 'TV', 'TV', 'TV', 'Husuma', 'Chabudai', 'Chabudai', 'Chabudai', 'Chabudai', 'TV', 'TV', 'Husuma', 'Chabudai', 'TV', 'Husuma', 'TV', 'Husuma', 'Chabudai', 'Chabudai', 'Chabudai', 'TV', 'TV', 'Husuma', 'Chabudai', 'TV', 'Husuma', 'TV', 'Husuma', 'Chabudai', 'TV', 'TV', 'Husuma', 'Chabudai', 'Husuma', 'TV', 'Husuma', 'TV', 'Husuma', 'TV', 'TV', 'Husuma', 'TV', 'Husuma', 'Chabudai', 'TV', 'Husuma', 'TV', 'Husuma', 'Chabudai', 'TV', 'Husuma', 'Chabudai', 'TV', 'Husuma', 'Chabudai', 'TV', 'Husuma', 'Chabudai', 'Chabudai', 'TV', 'Husuma', 'Husuma', 'TV', 'TV', 'TV', 'TV', 'Husuma', 'TV', 'Husuma', 'TV', 'Husuma', 'TV', 'Husuma', 'TV', 'Husuma', 'TV', 'Husuma', 'TV', 'TV', 'TV', 'Husuma', 'Husuma', 'Chabudai', 'TV', 'TV', 'Husuma', 'Chabudai', 'TV', 'Husuma', 'Husuma', 'Chabudai', 'TV', 'TV', 'Husuma', 'TV', 'Husuma', 'Chabudai', 'TV', 'Husuma', 'Chabudai', 'TV', 'TV', 'TV', 'Husuma', 'TV', 'Husuma', 'TV', 'Husuma', 'TV', 'TV', 'TV', 'Husuma', 'Chabudai', 'TV', 'Husuma', 'TV', 'TV', 'Husuma', 'Chabudai', 'TV', 'TV', 'TV', 'Husuma', 'TV', 'Husuma', 'TV', 'Husuma', 'TV', 'Husuma', 'Chabudai', 'TV', 'TV', 'Husuma', 'TV', 'TV', 'TV', 'Husuma', 'TV', 'Husuma', 'Chabudai', 'TV', 'TV', 'Husuma', 'TV', 'Husuma', 'TV', 'TV', 'TV', 'Husuma', 'Chabudai', 'Chabudai', 'TV', 'Husuma', 'Chabudai', 'TV', 'Husuma', 'Chabudai', 'Chabudai', 'TV', 'TV', 'Husuma', 'Chabudai', 'TV', 'TV', 'Husuma', 'Chabudai', 'TV', 'Husuma', 'TV', 'Husuma', 'Chabudai', 'Chabudai', 'TV', 'TV', 'Husuma', 'Husuma', 'TV', 'Husuma', 'Husuma', 'Chabudai', 'Chabudai', 'TV', 'Husuma', 'TV', 'Husuma', 'TV', 'TV', 'TV', 'Husuma', 'Chabudai', 'TV', 'Husuma', 'TV', 'TV', 'TV', 'TV', 'TV', 'Husuma', 'Chabudai', 'Chabudai', 'TV', 'TV', 'TV', 'Husuma', 'TV', 'Husuma', 'Chabudai', 'TV', 'Husuma', 'TV', 'TV', 'Husuma', 'Chabudai', 'Chabudai', 'Chabudai', 'TV', 'Husuma', 'Husuma', 'TV', 'Husuma', 'TV', 'TV', 'Husuma', 'Chabudai', 'Husuma', 'TV', 'Husuma', 'Chabudai', 'TV', 'TV', 'Husuma', 'TV', 'Husuma', 'TV', 'Husuma', 'Chabudai', 'Husuma', 'TV', 'Husuma', 'TV', 'TV', 'Husuma', 'TV', 'Husuma', 'Chabudai', 'TV', 'TV', 'Husuma', 'TV', 'TV', 'Husuma', 'TV', 'TV', 'Husuma', 'TV', 'TV', ' ...
#
# Cの定常確率:5.263157894736842->23.076923076923077->13.559322033898304->13.924050632911392->16.161616161616163->15.966386554621847->19.424460431654676->11.320754716981133->15.64245810055866->8.542713567839195->11.87214611872146->10.87866108786611->11.196911196911197->7.526881720430108->12.709030100334449->11.598746081504702->12.094395280235988->14.206128133704734->13.984168865435356->13.032581453634084->15.513126491646778->14.123006833712983->13.28976034858388->11.899791231732777->11.022044088176353->15.79961464354528->12.615955473098332->15.20572450805009->13.989637305699482->14.524207011686144->17.2859450726979->
#
# Hの定常確率:26.31578947368421->25.64102564102564->37.28813559322034->34.177215189873415->32.323232323232325->31.092436974789916->30.935251798561154->31.446540880503143->31.28491620111732->28.14070351758794->30.136986301369863->32.63598326359833->30.115830115830118->32.97491039426524->36.12040133779264->32.9153605015674->32.743362831858406->33.70473537604457->29.815303430079155->30.576441102756892->30.787589498806682->31.207289293849662->33.33333333333333->31.106471816283925->31.663326653306612->32.947976878612714->30.426716141001855->31.84257602862254->30.05181347150259->32.220367278797994->33.117932148626814->
#
# Tの定常確率:68.42105263157895->51.28205128205128->49.152542372881356->51.89873417721519->51.515151515151516->52.94117647058824->49.64028776978417->57.23270440251572->53.072625698324025->63.31658291457286->57.99086757990868->56.48535564853556->58.68725868725869->59.49820788530465->51.17056856187291->55.4858934169279->55.16224188790561->52.089136490250695->56.200527704485495->56.390977443609025->53.699284009546545->54.66970387243736->53.37690631808278->56.9937369519833->57.31462925851704->51.252408477842->56.95732838589982->52.95169946332737->55.95854922279793->53.255425709515855->49.59612277867528->
