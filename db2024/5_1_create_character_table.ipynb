# %%
import random

#!/usr/bin/env python
# -*- coding: utf-8 -*-

import sqlite3
import random
import datetime

# the number of characters: 100
# the number of players: 30

dbname = 'cit-db-2024-05.db'
conn = sqlite3.connect(dbname)

cur = conn.cursor()

try:
	comstr1 = "drop table character;"
	cur.execute(comstr1)

except:
	pass

#comstr2 = "create table character (player_id INTEGER PRIMARY KEY AUTOINCREMENT, character_id INTEGER, character_name VARCHAR(20), HP INTERGER, MP INTEGER, EXP INTEGER);"
comstr2 = "create table character (character_id INTEGER, player_id INTEGER, character_name VARCHAR(20), HP INTERGER, MP INTEGER, EXP INTEGER);"

cur.execute(comstr2)
conn.commit()

for number in range(100):

	l = ['doraemon', 'akinator', 'golgo', 'begita', 'bikkuriko']
	l_weight = [10, 1, 1, 1, 1]
	
	character_name = random.choices(l, weights=l_weight)
	
	#print(character_name[0])
	
	#point  = random.randrange(0, 5, 1)
	#print(str(point) + "," + l[point])
	
	playerID  = random.randrange(1, 30, 1)
	
	HP  = random.randrange(1, 100, 1)
	MP  = random.randrange(1, 100, 1)
	EXP  = random.randrange(1, 100, 1)

	comstr = "insert into character (character_id, player_id, character_name, HP, MP, EXP) values(" +  str(number) + "," + str(playerID) + ",'" + str(character_name[0]) + "'," + str(HP) + "," + str(MP) + "," + str(EXP) + ");"
	print(comstr)
	cur.execute(comstr)

	conn.commit()

cur = conn.cursor()
cur.execute('select * from character limit 10')

for row in cur:
	print(row)

cur.close()
conn.close()
# Out:
# insert into character (character_id, player_id, character_name, HP, MP, EXP) values(0,15,'doraemon',14,54,14);
# insert into character (character_id, player_id, character_name, HP, MP, EXP) values(1,3,'doraemon',21,47,42);
# insert into character (character_id, player_id, character_name, HP, MP, EXP) values(2,19,'doraemon',38,16,20);
# insert into character (character_id, player_id, character_name, HP, MP, EXP) values(3,5,'golgo',60,69,65);
# insert into character (character_id, player_id, character_name, HP, MP, EXP) values(4,18,'begita',26,56,23);
# insert into character (character_id, player_id, character_name, HP, MP, EXP) values(5,1,'doraemon',16,54,83);
# insert into character (character_id, player_id, character_name, HP, MP, EXP) values(6,9,'akinator',51,51,60);
# insert into character (character_id, player_id, character_name, HP, MP, EXP) values(7,24,'doraemon',75,84,3);
# insert into character (character_id, player_id, character_name, HP, MP, EXP) values(8,12,'doraemon',53,70,18);
# insert into character (character_id, player_id, character_name, HP, MP, EXP) values(9,11,'begita',55,75,98);
# insert into character (character_id, player_id, character_name, HP, MP, EXP) values(10,25,'doraemon',86,67,41);
# insert into character (character_id, player_id, character_name, HP, MP, EXP) values(11,8,'doraemon',76,12,71);
# insert into character (character_id, player_id, character_name, HP, MP, EXP) values(12,13,'doraemon',81,66,15);
# insert into character (character_id, player_id, character_name, HP, MP, EXP) values(13,19,'bikkuriko',72,59,93);
# insert into character (character_id, player_id, character_name, HP, MP, EXP) values(14,9,'doraemon',44,82,86);
# insert into character (character_id, player_id, character_name, HP, MP, EXP) values(15,24,'golgo',73,7,63);
# insert into character (character_id, player_id, character_name, HP, MP, EXP) values(16,21,'bikkuriko',48,9,26);
# insert into character (character_id, player_id, character_name, HP, MP, EXP) values(17,1,'bikkuriko',20,13,47);
# insert into character (character_id, player_id, character_name, HP, MP, EXP) values(18,11,'akinator',37,87,11);
# insert into character (character_id, player_id, character_name, HP, MP, EXP) values(19,28,'doraemon',75,82,59);
# insert into character (character_id, player_id, character_name, HP, MP, EXP) values(20,22,'doraemon',29,41,34);
# insert into character (character_id, player_id, character_name, HP, MP, EXP) values(21,1,'doraemon',31,60,63);
# insert into character (character_id, player_id, character_name, HP, MP, EXP) values(22,18,'doraemon',95,75,2);
# insert into character (character_id, player_id, character_name, HP, MP, EXP) values(23,20,'doraemon',7,97,21);
# insert into character (character_id, player_id, character_name, HP, MP, EXP) values(24,19,'golgo',3,46,71);
# insert into character (character_id, player_id, character_name, HP, MP, EXP) values(25,27,'doraemon',20,95,94);
# insert into character (character_id, player_id, character_name, HP, MP, EXP) values(26,10,'doraemon',58,92,28);
# insert into character (character_id, player_id, character_name, HP, MP, EXP) values(27,20,'begita',46,67,31);
# insert into character (character_id, player_id, character_name, HP, MP, EXP) values(28,28,'doraemon',12,88,14);
# insert into character (character_id, player_id, character_name, HP, MP, EXP) values(29,23,'doraemon',1,97,72);
# insert into character (character_id, player_id, character_name, HP, MP, EXP) values(30,21,'doraemon',50,6,97);
# insert into character (character_id, player_id, character_name, HP, MP, EXP) values(31,21,'bikkuriko',54,50,9);
# insert into character (character_id, player_id, character_name, HP, MP, EXP) values(32,29,'bikkuriko',5,33,81);
# insert into character (character_id, player_id, character_name, HP, MP, EXP) values(33,8,'bikkuriko',48,85,17);
# insert into character (character_id, player_id, character_name, HP, MP, EXP) values(34,24,'doraemon',41,40,47);
# insert into character (character_id, player_id, character_name, HP, MP, EXP) values(35,11,'doraemon',78,3,56);
# insert into character (character_id, player_id, character_name, HP, MP, EXP) values(36,13,'doraemon',16,88,6);
# insert into character (character_id, player_id, character_name, HP, MP, EXP) values(37,22,'akinator',94,44,7);
# insert into character (character_id, player_id, character_name, HP, MP, EXP) values(38,28,'golgo',85,82,65);
# insert into character (character_id, player_id, character_name, HP, MP, EXP) values(39,20,'doraemon',10,55,23);
# insert into character (character_id, player_id, character_name, HP, MP, EXP) values(40,11,'doraemon',33,44,50);
# insert into character (character_id, player_id, character_name, HP, MP, EXP) values(41,27,'golgo',45,42,12);
# insert into character (character_id, player_id, character_name, HP, MP, EXP) values(42,7,'doraemon',4,31,75);
# insert into character (character_id, player_id, character_name, HP, MP, EXP) values(43,5,'akinator',44,98,18);
# insert into character (character_id, player_id, character_name, HP, MP, EXP) values(44,2,'akinator',39,23,56);
# insert into character (character_id, player_id, character_name, HP, MP, EXP) values(45,6,'doraemon',55,4,52);
# insert into character (character_id, player_id, character_name, HP, MP, EXP) values(46,12,'doraemon',73,48,91);
# insert into character (character_id, player_id, character_name, HP, MP, EXP) values(47,9,'doraemon',95,40,14);
# insert into character (character_id, player_id, character_name, HP, MP, EXP) values(48,12,'bikkuriko',70,70,24);
# insert into character (character_id, player_id, character_name, HP, MP, EXP) values(49,22,'akinator',38,57,42);
# insert into character (character_id, player_id, character_name, HP, MP, EXP) values(50,8,'bikkuriko',43,89,84);
# insert into character (character_id, player_id, character_name, HP, MP, EXP) values(51,20,'bikkuriko',60,95,52);
# insert into character (character_id, player_id, character_name, HP, MP, EXP) values(52,29,'doraemon',78,55,19);
# insert into character (character_id, player_id, character_name, HP, MP, EXP) values(53,29,'doraemon',23,98,99);
# insert into character (character_id, player_id, character_name, HP, MP, EXP) values(54,5,'doraemon',78,55,34);
# insert into character (character_id, player_id, character_name, HP, MP, EXP) values(55,25,'doraemon',43,26,77);
# insert into character (character_id, player_id, character_name, HP, MP, EXP) values(56,12,'golgo',67,27,54);
# insert into character (character_id, player_id, character_name, HP, MP, EXP) values(57,10,'doraemon',39,74,78);
# insert into character (character_id, player_id, character_name, HP, MP, EXP) values(58,21,'golgo',40,22,54);
# insert into character (character_id, player_id, character_name, HP, MP, EXP) values(59,15,'begita',15,16,27);
# insert into character (character_id, player_id, character_name, HP, MP, EXP) values(60,9,'doraemon',1,27,60);
# insert into character (character_id, player_id, character_name, HP, MP, EXP) values(61,21,'begita',69,29,31);
# insert into character (character_id, player_id, character_name, HP, MP, EXP) values(62,8,'doraemon',58,48,17);
# insert into character (character_id, player_id, character_name, HP, MP, EXP) values(63,22,'begita',63,94,19);
# insert into character (character_id, player_id, character_name, HP, MP, EXP) values(64,9,'doraemon',52,69,10);
# insert into character (character_id, player_id, character_name, HP, MP, EXP) values(65,2,'doraemon',33,89,31);
# insert into character (character_id, player_id, character_name, HP, MP, EXP) values(66,14,'doraemon',5,31,62);
# insert into character (character_id, player_id, character_name, HP, MP, EXP) values(67,26,'akinator',25,61,66);
# insert into character (character_id, player_id, character_name, HP, MP, EXP) values(68,25,'begita',71,14,95);
# insert into character (character_id, player_id, character_name, HP, MP, EXP) values(69,24,'doraemon',91,35,18);
# insert into character (character_id, player_id, character_name, HP, MP, EXP) values(70,21,'doraemon',83,19,89);
# insert into character (character_id, player_id, character_name, HP, MP, EXP) values(71,2,'bikkuriko',75,88,36);
# insert into character (character_id, player_id, character_name, HP, MP, EXP) values(72,19,'doraemon',11,54,78);
# insert into character (character_id, player_id, character_name, HP, MP, EXP) values(73,13,'golgo',17,45,7);
# insert into character (character_id, player_id, character_name, HP, MP, EXP) values(74,23,'doraemon',26,33,58);
# insert into character (character_id, player_id, character_name, HP, MP, EXP) values(75,4,'doraemon',87,22,22);
# insert into character (character_id, player_id, character_name, HP, MP, EXP) values(76,16,'doraemon',92,74,74);
# insert into character (character_id, player_id, character_name, HP, MP, EXP) values(77,27,'doraemon',38,61,1);
# insert into character (character_id, player_id, character_name, HP, MP, EXP) values(78,3,'akinator',99,87,60);
# insert into character (character_id, player_id, character_name, HP, MP, EXP) values(79,26,'doraemon',72,77,69);
# insert into character (character_id, player_id, character_name, HP, MP, EXP) values(80,17,'doraemon',12,20,13);
# insert into character (character_id, player_id, character_name, HP, MP, EXP) values(81,16,'doraemon',2,60,32);
# insert into character (character_id, player_id, character_name, HP, MP, EXP) values(82,25,'doraemon',34,77,15);
# insert into character (character_id, player_id, character_name, HP, MP, EXP) values(83,18,'doraemon',23,45,24);
# insert into character (character_id, player_id, character_name, HP, MP, EXP) values(84,2,'akinator',46,86,2);
# insert into character (character_id, player_id, character_name, HP, MP, EXP) values(85,17,'doraemon',40,40,23);
# insert into character (character_id, player_id, character_name, HP, MP, EXP) values(86,1,'doraemon',13,90,32);
# insert into character (character_id, player_id, character_name, HP, MP, EXP) values(87,17,'begita',66,93,46);
# insert into character (character_id, player_id, character_name, HP, MP, EXP) values(88,2,'begita',95,90,77);
# insert into character (character_id, player_id, character_name, HP, MP, EXP) values(89,7,'doraemon',39,52,54);
# insert into character (character_id, player_id, character_name, HP, MP, EXP) values(90,2,'golgo',18,98,15);
# insert into character (character_id, player_id, character_name, HP, MP, EXP) values(91,24,'doraemon',60,99,26);
# insert into character (character_id, player_id, character_name, HP, MP, EXP) values(92,7,'doraemon',63,83,80);
# insert into character (character_id, player_id, character_name, HP, MP, EXP) values(93,16,'begita',91,4,6);
# insert into character (character_id, player_id, character_name, HP, MP, EXP) values(94,22,'doraemon',17,95,54);
# insert into character (character_id, player_id, character_name, HP, MP, EXP) values(95,27,'golgo',66,19,89);
# insert into character (character_id, player_id, character_name, HP, MP, EXP) values(96,2,'akinator',12,34,76);
# insert into character (character_id, player_id, character_name, HP, MP, EXP) values(97,13,'doraemon',27,18,17);
# insert into character (character_id, player_id, character_name, HP, MP, EXP) values(98,18,'doraemon',56,50,64);
# insert into character (character_id, player_id, character_name, HP, MP, EXP) values(99,21,'akinator',65,11,35);
# (0, 15, 'doraemon', 14, 54, 14)
# (1, 3, 'doraemon', 21, 47, 42)
# (2, 19, 'doraemon', 38, 16, 20)
# (3, 5, 'golgo', 60, 69, 65)
# (4, 18, 'begita', 26, 56, 23)
# (5, 1, 'doraemon', 16, 54, 83)
# (6, 9, 'akinator', 51, 51, 60)
# (7, 24, 'doraemon', 75, 84, 3)
# (8, 12, 'doraemon', 53, 70, 18)
# (9, 11, 'begita', 55, 75, 98)
# 現在のセルまたは前のセルでコードを実行中に、カーネル (Kernel) がクラッシュしました。
#
# エラーの原因を特定するには、セル内のコードを確認してください。
#
# 詳細については<a href='https://aka.ms/vscodeJupyterKernelCrash'>こちら</a>をクリックします。
#
# 詳細については、Jupyter <a href='command:jupyter.viewOutput'>ログ</a> を参照してください。
