# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-

import sqlite3
import random
import datetime

import string

# the number of characters: 100
# the number of players: 30

LETTERS = string.ascii_letters
#LETTERS = string.ascii_letters + string.digits + string.punctuation

def get_random_string(num):

    random_letters = random.choices(LETTERS, k=num 
    random_string = ''.join(random_letters)
    return random_string

dbname = 'cit-db-2024-05.db'
conn = sqlite3.connect(dbname)
cur = conn.cursor()

try:
	comstr1 = "drop table player;"
	cur.execute(comstr1)

except:
	pass

#comstr2 = "create table player (person_id INTEGER PRIMARY KEY AUTOINCREMENT, fname VARCHAR(20), lname VARCHAR(20), points INTEGER, rank VARCHAR(20));"
comstr2 = "create table player (player_id INTEGER, fname VARCHAR(20), lname VARCHAR(20), points INTEGER, rank VARCHAR(20));"
# 3.テーブルに人名データを登録する
cur.execute(comstr2)

for number in range(30):

	fname = get_random_string(5)
	#print(fname)

	lname = get_random_string(5)
	#print(lname)

	rank = ''.join(random.choices(string.ascii_uppercase, k=1))
	#print(rank)

	point  = random.randrange(1, 100, 1)
	#print(point)

	comstr = "insert into player (player_id, fname, lname, points, rank) values('" + str(number) + "','" + fname + "','" + lname + "','" + str(point) + "','" + rank + "');"
	print(comstr)

	cur.execute(comstr)
	conn.commit()

	cur = conn.cursor()
	cur.execute('select * from player limit 10')

for row in cur:
	print(row)

cur.close()
conn.close()
# Out:
# insert into player (player_id, fname, lname, points, rank) values('0','Mjzxr','CZsIh','86','P');
# insert into player (player_id, fname, lname, points, rank) values('1','sMBWd','Dsvhv','53','B');
# insert into player (player_id, fname, lname, points, rank) values('2','IczjS','vmFSp','45','Y');
# insert into player (player_id, fname, lname, points, rank) values('3','sJFRD','CBCQf','35','P');
# insert into player (player_id, fname, lname, points, rank) values('4','ORsLl','NnvBJ','35','P');
# insert into player (player_id, fname, lname, points, rank) values('5','ocxEx','ADmsL','42','E');
# insert into player (player_id, fname, lname, points, rank) values('6','LbovD','gkgsR','20','Z');
# insert into player (player_id, fname, lname, points, rank) values('7','DySup','THYai','21','D');
# insert into player (player_id, fname, lname, points, rank) values('8','HYQih','EtWqL','74','H');
# insert into player (player_id, fname, lname, points, rank) values('9','rUmTI','iSNwG','11','X');
# insert into player (player_id, fname, lname, points, rank) values('10','bbqhA','RcVkY','33','V');
# insert into player (player_id, fname, lname, points, rank) values('11','alPNC','QgpjX','69','D');
# insert into player (player_id, fname, lname, points, rank) values('12','OjlMW','EFnlY','48','U');
# insert into player (player_id, fname, lname, points, rank) values('13','sYVsC','OunxT','19','L');
# insert into player (player_id, fname, lname, points, rank) values('14','Dywqf','NCFSX','91','Q');
# insert into player (player_id, fname, lname, points, rank) values('15','Vzhgg','PaTeW','1','M');
# insert into player (player_id, fname, lname, points, rank) values('16','rGUpd','ODYgm','39','C');
# insert into player (player_id, fname, lname, points, rank) values('17','ROGnG','yQUyo','83','O');
# insert into player (player_id, fname, lname, points, rank) values('18','EVuup','AlPYn','37','U');
# insert into player (player_id, fname, lname, points, rank) values('19','wcExA','GbnnB','53','U');
# insert into player (player_id, fname, lname, points, rank) values('20','vSNTi','WVBHl','3','Q');
# insert into player (player_id, fname, lname, points, rank) values('21','UdYWn','SicnM','6','W');
# insert into player (player_id, fname, lname, points, rank) values('22','sMUCr','GMsUr','34','Q');
# insert into player (player_id, fname, lname, points, rank) values('23','RXBWM','Hizfu','49','Q');
# insert into player (player_id, fname, lname, points, rank) values('24','tSqtP','JJmkZ','85','V');
# insert into player (player_id, fname, lname, points, rank) values('25','Bchie','OcdJM','94','S');
# insert into player (player_id, fname, lname, points, rank) values('26','ZTrLs','jgTZn','25','V');
# insert into player (player_id, fname, lname, points, rank) values('27','CVVMq','WKjJS','63','D');
# insert into player (player_id, fname, lname, points, rank) values('28','PxmHh','veBfC','47','E');
# insert into player (player_id, fname, lname, points, rank) values('29','BVFgE','KptqA','11','D');
# (0, 'Mjzxr', 'CZsIh', 86, 'P')
# (1, 'sMBWd', 'Dsvhv', 53, 'B')
# (2, 'IczjS', 'vmFSp', 45, 'Y')
# (3, 'sJFRD', 'CBCQf', 35, 'P')
# (4, 'ORsLl', 'NnvBJ', 35, 'P')
# (5, 'ocxEx', 'ADmsL', 42, 'E')
# (6, 'LbovD', 'gkgsR', 20, 'Z')
# (7, 'DySup', 'THYai', 21, 'D')
# (8, 'HYQih', 'EtWqL', 74, 'H')
# (9, 'rUmTI', 'iSNwG', 11, 'X')
