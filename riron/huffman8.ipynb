# %%
import numpy as np
import random as rm
import sys

# The statespace
states = ["Chabudai","Husuma","TV"]

transitionName = [["CC","CT","CH"],["HH","HT","HC"],["TT","TH","TC"]]
transitionMatrix = [[0.2,0.6,0.2],[0.1,0.6,0.3],[0.2,0.7,0.1]]

if sum(transitionMatrix[0])+sum(transitionMatrix[1])+sum(transitionMatrix[1]) != 3:
    print("Transition matrix is wrong.")
else: print("")

alist = []
rndstr = []

def randstr(length,b,e):
    return ''.join([chr(rm.randint(b, e)) for _ in range(length)])

def generate_sequence(days, cPos):
    # Choose the starting state
    currentPosition = cPos
    alist.append(currentPosition)
    #print("Start state: " + currentPosition)
    # Shall store the sequence of states taken. So, this only has the starting state for now.
    activityList = [currentPosition]
    i = 0
    # To calculate the probability of the activityList
    prob = 1
    while i != days:
        if currentPosition == "Chabudai":
            change = np.random.choice(transitionName[0],replace=True,p=transitionMatrix[0])
            if change == "CC":
                prob = prob * 0.2
                activityList.append("Chabudai")
                alist.append("Chabudai")
                rndstr.append(randstr(10,75,85))
                pass
            elif change == "CT":
                prob = prob * 0.6
                currentPosition = "TV"
                activityList.append("TV")
                alist.append("TV")
                rndstr.append(randstr(10,65,75))
            else:
                prob = prob * 0.2
                currentPosition = "Husuma"
                activityList.append("Husuma")
                alist.append("Husuma")
                rndstr.append(randstr(10,85,90))
                
        elif currentPosition == "Husuma":
            change = np.random.choice(transitionName[1],replace=True,p=transitionMatrix[1])
            if change == "HC":
                prob = prob * 0.5
                activityList.append("Chabudai")
                alist.append("Chabudai")
                rndstr.append(randstr(10,75,85))
                pass
            elif change == "HT":
                prob = prob * 0.2
                currentPosition = "TV"
                activityList.append("TV")
                alist.append("TV")
                rndstr.append(randstr(10,75,85))
            else:
                prob = prob * 0.3
                currentPosition = "Husuma"
                activityList.append("Husuma")
                alist.append("Husuma")
                rndstr.append(randstr(10,85,90))
                
        elif currentPosition == "TV":
            change = np.random.choice(transitionName[2],replace=True,p=transitionMatrix[2])
            if change == "TC":
                prob = prob * 0.1
                activityList.append("Chabudai")
                alist.append("Chabudai")
                rndstr.append(randstr(10,75,85))
                pass
            elif change == "TH":
                prob = prob * 0.2
                currentPosition = "Husuma"
                activityList.append("Husuma")
                alist.append("Husuma")
                rndstr.append(randstr(10,85,90))
            else:
                prob = prob * 0.7
                currentPosition = "TV"
                activityList.append("TV")
                alist.append("TV")
                rndstr.append(randstr(10,65,75))
        i += 1  


#args = sys.argv
startPosition="TV"
LENGTH = 118

generate_sequence(LENGTH, startPosition)

Q_bak = []

outstr = ''
for i in rndstr:
    outstr = outstr + i

print(outstr)
    
from collections import Counter

def MIN_PRIORITY_QUEUE(S):
    return sorted(S.items(), key=lambda x: x[1], reverse=True)

def EXTRACT_MIN(Q):
    return Q.pop()

def INSERT(Q, z):
    return Q.append(z)

def HUFFMAN(S, a):
    n = len(S)
    Q = MIN_PRIORITY_QUEUE(S)
    #print(n)
    
    print("各文字の出現頻度")
    print(Q)
    
    
    print("")
    
    print("ハフマン木の構成")
    for i in range(n - 1):
        print(Q)
        left = EXTRACT_MIN(Q)
        right = EXTRACT_MIN(Q)
        #print(left)
        #print(right)
        freq = left[1] + right[1]
        z = (left[0] + right[0], freq)
        INSERT(Q, z)
        #print("left:")
        #print(left)
        #print("right:")
        #print(right)
        a.append([left, "0", left[0] + right[0]])
        a.append([right, "1", left[0] + right[0]])
        Q = dict(zip([i[0] for i in Q], [i[1] for i in Q]))
        Q = MIN_PRIORITY_QUEUE(Q)
    a.append([EXTRACT_MIN(Q), "", "top"])
    return a

def PrintReslut(b):
    for i in range(len(a)):
        now = a[i][0][0]
        num = a[i][1]
        j = 0
        while a[j][2] != 'top':
            if a[i][2] == a[j][0][0]:
                num = a[j][1] + num
                i = j
                flag = 0
                for k in range(len(a)):
                    if a[k][0][0] == 'top' or a[j][2] == a[k][0][0]:
                        flag = 1
                        break
            else:
                j += 1
        #print(s)
        if now in s:
            b.append([now, num])
    return b

def DivideS(S):
    S = list(S)
    S = Counter(S)
    S = dict(S)
    return S

print("-----")

ostr=outstr

sl = DivideS(ostr)
a = HUFFMAN(sl, [])

print("")
print("符号を割り当てる")

total_length = 0
total_length_2 = 0

for b in sorted(PrintReslut([])):
    l = len(b[1])
    outputstring = ""
    
    #print(sl[b[0]])
    lll = l * int(sl[b[0]])
    #print(lll)
    
    outputstring = b[0] +  ":" + b[1] + ":符号長:" + str(len(b[1])) + ":出現回数:" + str(sl[b[0]]) + ":総ビット長:" + str(lll)
    print(outputstring)
    
    total_length = total_length + lll
    #print(sl[b[0]] * 8)
    total_length_2 = total_length_2 + (sl[b[0]] * 8)
    
#print(total_length)
#print(total_length_2)
compression_rate = (total_length/total_length_2) * 100
print("")
print("圧縮率:" + str(compression_rate) + "%")
# Out:
# ...
# -----
# 各文字の出現頻度
# [('U', 136), ('X', 79), ('Q', 79), ('W', 76), ('V', 72), ('M', 71), ('K', 68), ('Z', 66), ('Y', 64), ('P', 64), ('T', 56), ('R', 56), ('N', 53), ('L', 52), ('O', 52), ('S', 51), ('A', 12), ('E', 11), ('I', 9), ('H', 9), ('D', 9), ('J', 9), ('B', 8), ('C', 7), ('G', 7), ('F', 4)]
#
# ハフマン木の構成
# [('U', 136), ('X', 79), ('Q', 79), ('W', 76), ('V', 72), ('M', 71), ('K', 68), ('Z', 66), ('Y', 64), ('P', 64), ('T', 56), ('R', 56), ('N', 53), ('L', 52), ('O', 52), ('S', 51), ('A', 12), ('E', 11), ('I', 9), ('H', 9), ('D', 9), ('J', 9), ('B', 8), ('C', 7), ('G', 7), ('F', 4)]
# [('U', 136), ('X', 79), ('Q', 79), ('W', 76), ('V', 72), ('M', 71), ('K', 68), ('Z', 66), ('Y', 64), ('P', 64), ('T', 56), ('R', 56), ('N', 53), ('L', 52), ('O', 52), ('S', 51), ('A', 12), ('E', 11), ('FG', 11), ('I', 9), ('H', 9), ('D', 9), ('J', 9), ('B', 8), ('C', 7)]
# [('U', 136), ('X', 79), ('Q', 79), ('W', 76), ('V', 72), ('M', 71), ('K', 68), ('Z', 66), ('Y', 64), ('P', 64), ('T', 56), ('R', 56), ('N', 53), ('L', 52), ('O', 52), ('S', 51), ('CB', 15), ('A', 12), ('E', 11), ('FG', 11), ('I', 9), ('H', 9), ('D', 9), ('J', 9)]
# [('U', 136), ('X', 79), ('Q', 79), ('W', 76), ('V', 72), ('M', 71), ('K', 68), ('Z', 66), ('Y', 64), ('P', 64), ('T', 56), ('R', 56), ('N', 53), ('L', 52), ('O', 52), ('S', 51), ('JD', 18), ('CB', 15), ('A', 12), ('E', 11), ('FG', 11), ('I', 9), ('H', 9)]
# [('U', 136), ('X', 79), ('Q', 79), ('W', 76), ('V', 72), ('M', 71), ('K', 68), ('Z', 66), ('Y', 64), ('P', 64), ('T', 56), ('R', 56), ('N', 53), ('L', 52), ('O', 52), ('S', 51), ('JD', 18), ('HI', 18), ('CB', 15), ('A', 12), ('E', 11), ('FG', 11)]
# [('U', 136), ('X', 79), ('Q', 79), ('W', 76), ('V', 72), ('M', 71), ('K', 68), ('Z', 66), ('Y', 64), ('P', 64), ('T', 56), ('R', 56), ('N', 53), ('L', 52), ('O', 52), ('S', 51), ('FGE', 22), ('JD', 18), ('HI', 18), ('CB', 15), ('A', 12)]
# [('U', 136), ('X', 79), ('Q', 79), ('W', 76), ('V', 72), ('M', 71), ('K', 68), ('Z', 66), ('Y', 64), ('P', 64), ('T', 56), ('R', 56), ('N', 53), ('L', 52), ('O', 52), ('S', 51), ('ACB', 27), ('FGE', 22), ('JD', 18), ('HI', 18)]
# [('U', 136), ('X', 79), ('Q', 79), ('W', 76), ('V', 72), ('M', 71), ('K', 68), ('Z', 66), ('Y', 64), ('P', 64), ('T', 56), ('R', 56), ('N', 53), ('L', 52), ('O', 52), ('S', 51), ('HIJD', 36), ('ACB', 27), ('FGE', 22)]
# [('U', 136), ('X', 79), ('Q', 79), ('W', 76), ('V', 72), ('M', 71), ('K', 68), ('Z', 66), ('Y', 64), ('P', 64), ('T', 56), ('R', 56), ('N', 53), ('L', 52), ('O', 52), ('S', 51), ('FGEACB', 49), ('HIJD', 36)]
# [('U', 136), ('HIJDFGEACB', 85), ('X', 79), ('Q', 79), ('W', 76), ('V', 72), ('M', 71), ('K', 68), ('Z', 66), ('Y', 64), ('P', 64), ('T', 56), ('R', 56), ('N', 53), ('L', 52), ('O', 52), ('S', 51)]
# [('U', 136), ('SO', 103), ('HIJDFGEACB', 85), ('X', 79), ('Q', 79), ('W', 76), ('V', 72), ('M', 71), ('K', 68), ('Z', 66), ('Y', 64), ('P', 64), ('T', 56), ('R', 56), ('N', 53), ('L', 52)]
# [('U', 136), ('LN', 105), ('SO', 103), ('HIJDFGEACB', 85), ('X', 79), ('Q', 79), ('W', 76), ('V', 72), ('M', 71), ('K', 68), ('Z', 66), ('Y', 64), ('P', 64), ('T', 56), ('R', 56)]
# [('U', 136), ('RT', 112), ('LN', 105), ('SO', 103), ('HIJDFGEACB', 85), ('X', 79), ('Q', 79), ('W', 76), ('V', 72), ('M', 71), ('K', 68), ('Z', 66), ('Y', 64), ('P', 64)]
# [('U', 136), ('PY', 128), ('RT', 112), ('LN', 105), ('SO', 103), ('HIJDFGEACB', 85), ('X', 79), ('Q', 79), ('W', 76), ('V', 72), ('M', 71), ('K', 68), ('Z', 66)]
# [('U', 136), ('ZK', 134), ('PY', 128), ('RT', 112), ('LN', 105), ('SO', 103), ('HIJDFGEACB', 85), ('X', 79), ('Q', 79), ('W', 76), ('V', 72), ('M', 71)]
# [('MV', 143), ('U', 136), ('ZK', 134), ('PY', 128), ('RT', 112), ('LN', 105), ('SO', 103), ('HIJDFGEACB', 85), ('X', 79), ('Q', 79), ('W', 76)]
# [('WQ', 155), ('MV', 143), ('U', 136), ('ZK', 134), ('PY', 128), ('RT', 112), ('LN', 105), ('SO', 103), ('HIJDFGEACB', 85), ('X', 79)]
# [('XHIJDFGEACB', 164), ('WQ', 155), ('MV', 143), ('U', 136), ('ZK', 134), ('PY', 128), ('RT', 112), ('LN', 105), ('SO', 103)]
# [('SOLN', 208), ('XHIJDFGEACB', 164), ('WQ', 155), ('MV', 143), ('U', 136), ('ZK', 134), ('PY', 128), ('RT', 112)]
# [('RTPY', 240), ('SOLN', 208), ('XHIJDFGEACB', 164), ('WQ', 155), ('MV', 143), ('U', 136), ('ZK', 134)]
# [('ZKU', 270), ('RTPY', 240), ('SOLN', 208), ('XHIJDFGEACB', 164), ('WQ', 155), ('MV', 143)]
# [('MVWQ', 298), ('ZKU', 270), ('RTPY', 240), ('SOLN', 208), ('XHIJDFGEACB', 164)]
# [('XHIJDFGEACBSOLN', 372), ('MVWQ', 298), ('ZKU', 270), ('RTPY', 240)]
# [('RTPYZKU', 510), ('XHIJDFGEACBSOLN', 372), ('MVWQ', 298)]
# [('MVWQXHIJDFGEACBSOLN', 670), ('RTPYZKU', 510)]
#
# 符号を割り当てる
# A:1101110:符号長:7:出現回数:12:総ビット長:84
# B:11011111:符号長:8:出現回数:8:総ビット長:64
# C:11011110:符号長:8:出現回数:7:総ビット長:56
# D:1101011:符号長:7:出現回数:9:総ビット長:63
# E:1101101:符号長:7:出現回数:11:総ビット長:77
# F:11011000:符号長:8:出現回数:4:総ビット長:32
# G:11011001:符号長:8:出現回数:7:総ビット長:56
# H:1101000:符号長:7:出現回数:9:総ビット長:63
# I:1101001:符号長:7:出現回数:9:総ビット長:63
# J:1101010:符号長:7:出現回数:9:総ビット長:63
# K:0101:符号長:4:出現回数:68:総ビット長:272
# L:11110:符号長:5:出現回数:52:総ビット長:260
# M:1000:符号長:4:出現回数:71:総ビット長:284
# N:11111:符号長:5:出現回数:53:総ビット長:265
# O:11101:符号長:5:出現回数:52:総ビット長:260
# P:0010:符号長:4:出現回数:64:総ビット長:256
# Q:1011:符号長:4:出現回数:79:総ビット長:316
# R:0000:符号長:4:出現回数:56:総ビット長:224
# S:11100:符号長:5:出現回数:51:総ビット長:255
# T:0001:符号長:4:出現回数:56:総ビット長:224
# U:011:符号長:3:出現回数:136:総ビット長:408
# V:1001:符号長:4:出現回数:72:総ビット長:288
# W:1010:符号長:4:出現回数:76:総ビット長:304
# X:1100:符号長:4:出現回数:79:総ビット長:316
# Y:0011:符号長:4:出現回数:64:総ビット長:256
# Z:0100:符号長:4:出現回数:66:総ビット長:264
#
# 圧縮率:53.73940677966102%
