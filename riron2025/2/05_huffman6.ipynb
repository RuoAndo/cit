# %%
from collections import Counter

def MIN_PRIORITY_QUEUE(S):
    return sorted(S.items(), key=lambda x: x[1], reverse=True)

def EXTRACT_MIN(Q):
    return Q.pop()

def INSERT(Q, z):
    return Q.append(z)

def HUFFMAN(S, a):
    n = len(S)
    Q = MIN_PRIORITY_QUEUE(S)
   
    print("各文字の出現頻度")
    print(Q)
    print("")
    
    for i in range(n - 1):
        
        left = EXTRACT_MIN(Q)
        right = EXTRACT_MIN(Q)

        #print(left)
        #print(right)
        
        freq = left[1] + right[1]
        z = (left[0] + right[0], freq)
        
        #print(z)
        
        INSERT(Q, z)

        a.append([left, "0", "right", left[0] + right[0]])
        a.append([right, "1", "left", left[0] + right[0]])
        
        #print(a)
    
        
        Q = dict(zip([i[0] for i in Q], [i[1] for i in Q]))
        
        Q = MIN_PRIORITY_QUEUE(Q)
        
    a.append([EXTRACT_MIN(Q), "", "", "top"])
    
    print(a)
    return a

def DivideS(S):
    S = list(S)
    S = Counter(S)
    S = dict(S)
    return S

def PrintReslut(b):
    for i in range(len(a)):
        now = a[i][0][0]
        num = a[i][1]
        j = 0
        while a[j][3] != 'top':
            if a[i][3] == a[j][0][0]:
                num = a[j][1] + num
                i = j
                flag = 0
                for k in range(len(a)):
                    if a[k][0][0] == 'top' or a[j][2] == a[k][0][0]:
                        flag = 1
                        break
            else:
                j += 1
        if now in s:
            b.append([now, num])
    return b

import random

str = ""
for i in range(10):
    x = random.randint(65,70)
    str = str + chr(x)
 
print(str)
#str="ABBCACCEACBCCFABCDAFEABFFADBBC"

s = DivideS(str)
a = HUFFMAN(s, [])

for b in sorted(PrintReslut([])):
    print(b[0] + ": " + b[1])
# Out:
# FCFDBFEDEB
# 各文字の出現頻度
# [('F', 3), ('D', 2), ('B', 2), ('E', 2), ('C', 1)]
#
# [[('C', 1), '0', 'right', 'CE'], [('E', 2), '1', 'left', 'CE'], [('B', 2), '0', 'right', 'BD'], [('D', 2), '1', 'left', 'BD'], [('CE', 3), '0', 'right', 'CEF'], [('F', 3), '1', 'left', 'CEF'], [('BD', 4), '0', 'right', 'BDCEF'], [('CEF', 6), '1', 'left', 'BDCEF'], [('BDCEF', 10), '', '', 'top']]
# B: 00
# C: 100
# D: 01
# E: 101
# F: 11
