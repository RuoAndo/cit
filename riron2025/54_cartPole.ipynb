# %%
import gymnasium as gym
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import random
from collections import deque
import matplotlib.pyplot as plt
from matplotlib import animation
from IPython.display import display, HTML

# Q-Network
class DQN(nn.Module):
    def __init__(self, obs_size, n_actions):
        super(DQN, self).__init__()
        self.net = nn.Sequential(
            nn.Linear(obs_size, 128),
            nn.ReLU(),
            nn.Linear(128, n_actions)
        )

    def forward(self, x):
        return self.net(x)

# Replay Buffer
class ReplayBuffer:
    def __init__(self, capacity):
        self.buffer = deque(maxlen=capacity)

    def push(self, transition):
        self.buffer.append(transition)

    def sample(self, batch_size):
        return random.sample(self.buffer, batch_size)

    def __len__(self):
        return len(self.buffer)

# アニメーション作成関数
def display_frames_as_gif(frames, filename="cartpole.mp4"):
    plt.figure(figsize=(frames[0].shape[1] / 72.0, frames[0].shape[0] / 72.0), dpi=72)
    patch = plt.imshow(frames[0])
    plt.axis('off')

    def animate(i):
        patch.set_data(frames[i])
        return patch,

    anim = animation.FuncAnimation(plt.gcf(), animate, frames=len(frames), interval=50)
    anim.save(filename)
    plt.close()

# 学習本体
def train_cartpole():
    env = gym.make("CartPole-v1", render_mode="rgb_array")
    obs_size = env.observation_space.shape[0]
    n_actions = env.action_space.n

    policy_net = DQN(obs_size, n_actions)
    target_net = DQN(obs_size, n_actions)
    target_net.load_state_dict(policy_net.state_dict())
    target_net.eval()

    optimizer = optim.Adam(policy_net.parameters(), lr=1e-3)
    buffer = ReplayBuffer(10000)
    batch_size = 64
    gamma = 0.99
    epsilon = 1.0
    epsilon_decay = 0.995
    epsilon_min = 0.01

    episodes = 500
    final_frames = []  # 最後のエピソード用フレーム保存

    for episode in range(episodes):
        obs, _ = env.reset()
        total_reward = 0
        episode_frames = []

        for t in range(200):
            state = torch.FloatTensor(obs).unsqueeze(0)
            if random.random() < epsilon:
                action = env.action_space.sample()
            else:
                with torch.no_grad():
                    q_values = policy_net(state)
                    action = q_values.argmax().item()

            next_obs, reward, terminated, truncated, _ = env.step(action)
            done = terminated or truncated

            buffer.push((obs, action, reward, next_obs, done))
            obs = next_obs
            total_reward += reward

            # アニメーション用フレーム追加（最終エピソードのみ）
            if episode == episodes - 1:
                frame = env.render()
                episode_frames.append(frame)

            if len(buffer) >= batch_size:
                transitions = buffer.sample(batch_size)
                states, actions, rewards, next_states, dones = zip(*transitions)

                states_tensor = torch.FloatTensor(states)
                actions_tensor = torch.LongTensor(actions).unsqueeze(1)
                rewards_tensor = torch.FloatTensor(rewards).unsqueeze(1)
                next_states_tensor = torch.FloatTensor(next_states)
                dones_tensor = torch.FloatTensor(dones).unsqueeze(1)

                q_values = policy_net(states_tensor).gather(1, actions_tensor)
                next_q_values = target_net(next_states_tensor).max(1)[0].detach().unsqueeze(1)
                expected_q_values = rewards_tensor + gamma * next_q_values * (1 - dones_tensor)

                loss = nn.MSELoss()(q_values, expected_q_values)
                optimizer.zero_grad()
                loss.backward()
                optimizer.step()

            if done:
                break

        epsilon = max(epsilon_min, epsilon * epsilon_decay)
        if episode % 10 == 0:
            target_net.load_state_dict(policy_net.state_dict())

        print(f"Episode {episode}: total reward = {total_reward}")

        if episode == episodes - 1:
            final_frames = episode_frames

    env.close()
    display_frames_as_gif(final_frames, "cartpole_54.mp4")
    print("動画保存完了：cartpole.mp4")

if __name__ == "__main__":
    train_cartpole()
# Out:
# Episode 0: total reward = 32.0
# Episode 1: total reward = 26.0
# Episode 2: total reward = 40.0
# Episode 3: total reward = 18.0
# Episode 4: total reward = 48.0
# Episode 5: total reward = 28.0
# Episode 6: total reward = 22.0
# Episode 7: total reward = 27.0
# Episode 8: total reward = 15.0
# Episode 9: total reward = 19.0
# Episode 10: total reward = 12.0
# Episode 11: total reward = 11.0
# Episode 12: total reward = 12.0
# Episode 13: total reward = 19.0
# Episode 14: total reward = 20.0
# Episode 15: total reward = 25.0
# Episode 16: total reward = 66.0
# Episode 17: total reward = 16.0
# Episode 18: total reward = 26.0
# Episode 19: total reward = 15.0
# Episode 20: total reward = 21.0
# Episode 21: total reward = 39.0
# Episode 22: total reward = 23.0
# Episode 23: total reward = 15.0
# Episode 24: total reward = 23.0
# Episode 25: total reward = 18.0
# Episode 26: total reward = 29.0
# Episode 27: total reward = 25.0
# Episode 28: total reward = 21.0
# Episode 29: total reward = 23.0
# Episode 30: total reward = 29.0
# Episode 31: total reward = 10.0
# Episode 32: total reward = 14.0
# Episode 33: total reward = 33.0
# Episode 34: total reward = 13.0
# Episode 35: total reward = 12.0
# Episode 36: total reward = 20.0
# Episode 37: total reward = 12.0
# Episode 38: total reward = 22.0
# Episode 39: total reward = 26.0
# Episode 40: total reward = 50.0
# Episode 41: total reward = 26.0
# Episode 42: total reward = 48.0
# Episode 43: total reward = 36.0
# Episode 44: total reward = 27.0
# Episode 45: total reward = 22.0
# Episode 46: total reward = 71.0
# Episode 47: total reward = 23.0
# Episode 48: total reward = 27.0
# Episode 49: total reward = 96.0
# Episode 50: total reward = 36.0
# Episode 51: total reward = 18.0
# Episode 52: total reward = 20.0
# Episode 53: total reward = 15.0
# Episode 54: total reward = 48.0
# Episode 55: total reward = 133.0
# Episode 56: total reward = 22.0
# Episode 57: total reward = 25.0
# Episode 58: total reward = 49.0
# Episode 59: total reward = 20.0
# Episode 60: total reward = 20.0
# Episode 61: total reward = 13.0
# Episode 62: total reward = 36.0
# Episode 63: total reward = 36.0
# Episode 64: total reward = 40.0
# Episode 65: total reward = 22.0
# Episode 66: total reward = 30.0
# Episode 67: total reward = 19.0
# Episode 68: total reward = 56.0
# Episode 69: total reward = 36.0
# Episode 70: total reward = 37.0
# Episode 71: total reward = 49.0
# Episode 72: total reward = 83.0
# Episode 73: total reward = 19.0
# Episode 74: total reward = 99.0
# Episode 75: total reward = 43.0
# Episode 76: total reward = 15.0
# Episode 77: total reward = 45.0
# Episode 78: total reward = 62.0
# Episode 79: total reward = 136.0
# Episode 80: total reward = 26.0
# Episode 81: total reward = 139.0
# Episode 82: total reward = 99.0
# Episode 83: total reward = 105.0
# Episode 84: total reward = 106.0
# Episode 85: total reward = 58.0
# Episode 86: total reward = 87.0
# Episode 87: total reward = 39.0
# Episode 88: total reward = 19.0
# Episode 89: total reward = 34.0
# Episode 90: total reward = 25.0
# Episode 91: total reward = 61.0
# Episode 92: total reward = 48.0
# Episode 93: total reward = 24.0
# Episode 94: total reward = 117.0
# Episode 95: total reward = 24.0
# Episode 96: total reward = 73.0
# Episode 97: total reward = 103.0
# Episode 98: total reward = 137.0
# Episode 99: total reward = 90.0
# Episode 100: total reward = 65.0
# Episode 101: total reward = 114.0
# Episode 102: total reward = 15.0
# Episode 103: total reward = 96.0
# Episode 104: total reward = 143.0
# Episode 105: total reward = 17.0
# Episode 106: total reward = 47.0
# Episode 107: total reward = 142.0
# Episode 108: total reward = 24.0
# Episode 109: total reward = 114.0
# Episode 110: total reward = 98.0
# Episode 111: total reward = 12.0
# Episode 112: total reward = 141.0
# Episode 113: total reward = 157.0
# Episode 114: total reward = 189.0
# Episode 115: total reward = 122.0
# Episode 116: total reward = 168.0
# Episode 117: total reward = 116.0
# Episode 118: total reward = 17.0
# Episode 119: total reward = 166.0
# Episode 120: total reward = 72.0
# Episode 121: total reward = 58.0
# Episode 122: total reward = 16.0
# Episode 123: total reward = 113.0
# Episode 124: total reward = 24.0
# Episode 125: total reward = 101.0
# Episode 126: total reward = 91.0
# Episode 127: total reward = 67.0
# Episode 128: total reward = 193.0
# Episode 129: total reward = 155.0
# Episode 130: total reward = 161.0
# Episode 131: total reward = 153.0
# Episode 132: total reward = 200.0
# Episode 133: total reward = 118.0
# Episode 134: total reward = 60.0
# Episode 135: total reward = 49.0
# Episode 136: total reward = 82.0
# Episode 137: total reward = 11.0
# Episode 138: total reward = 57.0
# Episode 139: total reward = 61.0
# Episode 140: total reward = 200.0
# Episode 141: total reward = 178.0
# Episode 142: total reward = 82.0
# Episode 143: total reward = 200.0
# Episode 144: total reward = 84.0
# Episode 145: total reward = 170.0
# Episode 146: total reward = 103.0
# Episode 147: total reward = 167.0
# Episode 148: total reward = 122.0
# Episode 149: total reward = 62.0
# Episode 150: total reward = 164.0
# Episode 151: total reward = 37.0
# Episode 152: total reward = 84.0
# Episode 153: total reward = 158.0
# Episode 154: total reward = 25.0
# Episode 155: total reward = 166.0
# Episode 156: total reward = 200.0
# Episode 157: total reward = 58.0
# Episode 158: total reward = 147.0
# Episode 159: total reward = 45.0
# Episode 160: total reward = 200.0
# Episode 161: total reward = 29.0
# Episode 162: total reward = 14.0
# Episode 163: total reward = 122.0
# Episode 164: total reward = 106.0
# Episode 165: total reward = 14.0
# Episode 166: total reward = 100.0
# Episode 167: total reward = 200.0
# Episode 168: total reward = 200.0
# Episode 169: total reward = 167.0
# Episode 170: total reward = 195.0
# Episode 171: total reward = 172.0
# Episode 172: total reward = 200.0
# Episode 173: total reward = 30.0
# Episode 174: total reward = 200.0
# Episode 175: total reward = 200.0
# Episode 176: total reward = 85.0
# Episode 177: total reward = 170.0
# Episode 178: total reward = 107.0
# Episode 179: total reward = 148.0
# Episode 180: total reward = 200.0
# Episode 181: total reward = 200.0
# Episode 182: total reward = 48.0
# Episode 183: total reward = 79.0
# Episode 184: total reward = 199.0
# Episode 185: total reward = 200.0
# Episode 186: total reward = 180.0
# Episode 187: total reward = 200.0
# Episode 188: total reward = 200.0
# Episode 189: total reward = 200.0
# Episode 190: total reward = 200.0
# Episode 191: total reward = 200.0
# Episode 192: total reward = 46.0
# Episode 193: total reward = 200.0
# Episode 194: total reward = 200.0
# Episode 195: total reward = 72.0
# Episode 196: total reward = 200.0
# Episode 197: total reward = 200.0
# Episode 198: total reward = 99.0
# Episode 199: total reward = 200.0
# Episode 200: total reward = 200.0
# Episode 201: total reward = 168.0
# Episode 202: total reward = 15.0
# Episode 203: total reward = 200.0
# Episode 204: total reward = 200.0
# Episode 205: total reward = 200.0
# Episode 206: total reward = 200.0
# Episode 207: total reward = 200.0
# Episode 208: total reward = 90.0
# Episode 209: total reward = 36.0
# Episode 210: total reward = 200.0
# Episode 211: total reward = 110.0
# Episode 212: total reward = 74.0
# Episode 213: total reward = 200.0
# Episode 214: total reward = 40.0
# Episode 215: total reward = 200.0
# Episode 216: total reward = 45.0
# Episode 217: total reward = 170.0
# Episode 218: total reward = 71.0
# Episode 219: total reward = 200.0
# Episode 220: total reward = 200.0
# Episode 221: total reward = 200.0
# Episode 222: total reward = 200.0
# Episode 223: total reward = 196.0
# Episode 224: total reward = 200.0
# Episode 225: total reward = 25.0
# Episode 226: total reward = 200.0
# Episode 227: total reward = 200.0
# Episode 228: total reward = 174.0
# Episode 229: total reward = 88.0
# Episode 230: total reward = 200.0
# Episode 231: total reward = 200.0
# Episode 232: total reward = 193.0
# Episode 233: total reward = 200.0
# Episode 234: total reward = 200.0
# Episode 235: total reward = 200.0
# Episode 236: total reward = 186.0
# Episode 237: total reward = 200.0
# Episode 238: total reward = 200.0
# Episode 239: total reward = 200.0
# Episode 240: total reward = 200.0
# Episode 241: total reward = 200.0
# Episode 242: total reward = 200.0
# Episode 243: total reward = 121.0
# Episode 244: total reward = 200.0
# Episode 245: total reward = 200.0
# Episode 246: total reward = 187.0
# Episode 247: total reward = 200.0
# Episode 248: total reward = 200.0
# Episode 249: total reward = 163.0
# Episode 250: total reward = 200.0
# Episode 251: total reward = 79.0
# Episode 252: total reward = 200.0
# Episode 253: total reward = 200.0
# Episode 254: total reward = 200.0
# Episode 255: total reward = 200.0
# Episode 256: total reward = 53.0
# Episode 257: total reward = 200.0
# Episode 258: total reward = 200.0
# Episode 259: total reward = 182.0
# Episode 260: total reward = 200.0
# Episode 261: total reward = 156.0
# Episode 262: total reward = 115.0
# Episode 263: total reward = 200.0
# Episode 264: total reward = 200.0
# Episode 265: total reward = 55.0
# Episode 266: total reward = 200.0
# Episode 267: total reward = 200.0
# Episode 268: total reward = 200.0
# Episode 269: total reward = 34.0
# Episode 270: total reward = 47.0
# Episode 271: total reward = 59.0
# Episode 272: total reward = 200.0
# Episode 273: total reward = 200.0
# Episode 274: total reward = 200.0
# Episode 275: total reward = 200.0
# Episode 276: total reward = 200.0
# Episode 277: total reward = 200.0
# Episode 278: total reward = 200.0
# Episode 279: total reward = 200.0
# Episode 280: total reward = 200.0
# Episode 281: total reward = 200.0
# Episode 282: total reward = 200.0
# Episode 283: total reward = 200.0
# Episode 284: total reward = 200.0
# Episode 285: total reward = 200.0
# Episode 286: total reward = 168.0
# Episode 287: total reward = 200.0
# Episode 288: total reward = 86.0
# Episode 289: total reward = 200.0
# Episode 290: total reward = 200.0
# Episode 291: total reward = 200.0
# Episode 292: total reward = 200.0
# Episode 293: total reward = 25.0
# Episode 294: total reward = 200.0
# Episode 295: total reward = 200.0
# Episode 296: total reward = 200.0
# Episode 297: total reward = 48.0
# Episode 298: total reward = 200.0
# Episode 299: total reward = 186.0
# Episode 300: total reward = 200.0
# Episode 301: total reward = 173.0
# Episode 302: total reward = 184.0
# Episode 303: total reward = 200.0
# Episode 304: total reward = 200.0
# Episode 305: total reward = 56.0
# Episode 306: total reward = 200.0
# Episode 307: total reward = 200.0
# Episode 308: total reward = 200.0
# Episode 309: total reward = 200.0
# Episode 310: total reward = 128.0
# Episode 311: total reward = 154.0
# Episode 312: total reward = 200.0
# Episode 313: total reward = 200.0
# Episode 314: total reward = 200.0
# Episode 315: total reward = 200.0
# Episode 316: total reward = 200.0
# Episode 317: total reward = 200.0
# Episode 318: total reward = 200.0
# Episode 319: total reward = 200.0
# Episode 320: total reward = 200.0
# Episode 321: total reward = 200.0
# Episode 322: total reward = 164.0
# Episode 323: total reward = 200.0
# Episode 324: total reward = 200.0
# Episode 325: total reward = 196.0
# Episode 326: total reward = 200.0
# Episode 327: total reward = 200.0
# Episode 328: total reward = 200.0
# Episode 329: total reward = 32.0
# Episode 330: total reward = 175.0
# Episode 331: total reward = 200.0
# Episode 332: total reward = 200.0
# Episode 333: total reward = 178.0
# Episode 334: total reward = 200.0
# Episode 335: total reward = 200.0
# Episode 336: total reward = 200.0
# Episode 337: total reward = 200.0
# Episode 338: total reward = 37.0
# Episode 339: total reward = 26.0
# Episode 340: total reward = 73.0
# Episode 341: total reward = 200.0
# Episode 342: total reward = 200.0
# Episode 343: total reward = 200.0
# Episode 344: total reward = 200.0
# Episode 345: total reward = 200.0
# Episode 346: total reward = 31.0
# Episode 347: total reward = 200.0
# Episode 348: total reward = 200.0
# Episode 349: total reward = 200.0
# Episode 350: total reward = 200.0
# Episode 351: total reward = 162.0
# Episode 352: total reward = 161.0
# Episode 353: total reward = 162.0
# Episode 354: total reward = 171.0
# Episode 355: total reward = 187.0
# Episode 356: total reward = 187.0
# Episode 357: total reward = 153.0
# Episode 358: total reward = 200.0
# Episode 359: total reward = 150.0
# Episode 360: total reward = 148.0
# Episode 361: total reward = 156.0
# Episode 362: total reward = 17.0
# Episode 363: total reward = 173.0
# Episode 364: total reward = 146.0
# Episode 365: total reward = 130.0
# Episode 366: total reward = 188.0
# Episode 367: total reward = 143.0
# Episode 368: total reward = 136.0
# Episode 369: total reward = 174.0
# Episode 370: total reward = 148.0
# Episode 371: total reward = 122.0
# Episode 372: total reward = 182.0
# Episode 373: total reward = 163.0
# Episode 374: total reward = 85.0
# Episode 375: total reward = 200.0
# Episode 376: total reward = 128.0
# Episode 377: total reward = 200.0
# Episode 378: total reward = 152.0
# Episode 379: total reward = 200.0
# Episode 380: total reward = 155.0
# Episode 381: total reward = 166.0
# Episode 382: total reward = 200.0
# Episode 383: total reward = 177.0
# Episode 384: total reward = 165.0
# Episode 385: total reward = 159.0
# Episode 386: total reward = 107.0
# Episode 387: total reward = 193.0
# Episode 388: total reward = 147.0
# Episode 389: total reward = 160.0
# Episode 390: total reward = 154.0
# Episode 391: total reward = 181.0
# Episode 392: total reward = 152.0
# Episode 393: total reward = 144.0
# Episode 394: total reward = 133.0
# Episode 395: total reward = 73.0
# Episode 396: total reward = 139.0
# Episode 397: total reward = 161.0
# Episode 398: total reward = 154.0
# Episode 399: total reward = 149.0
# Episode 400: total reward = 148.0
# Episode 401: total reward = 127.0
# Episode 402: total reward = 145.0
# Episode 403: total reward = 146.0
# Episode 404: total reward = 152.0
# Episode 405: total reward = 148.0
# Episode 406: total reward = 125.0
# Episode 407: total reward = 154.0
# Episode 408: total reward = 130.0
# Episode 409: total reward = 143.0
# Episode 410: total reward = 126.0
# Episode 411: total reward = 43.0
# Episode 412: total reward = 148.0
# Episode 413: total reward = 129.0
# Episode 414: total reward = 130.0
# Episode 415: total reward = 138.0
# Episode 416: total reward = 133.0
# Episode 417: total reward = 132.0
# Episode 418: total reward = 131.0
# Episode 419: total reward = 147.0
# Episode 420: total reward = 113.0
# Episode 421: total reward = 129.0
# Episode 422: total reward = 153.0
# Episode 423: total reward = 126.0
# Episode 424: total reward = 125.0
# Episode 425: total reward = 130.0
# Episode 426: total reward = 132.0
# Episode 427: total reward = 127.0
# Episode 428: total reward = 133.0
# Episode 429: total reward = 122.0
# Episode 430: total reward = 116.0
# Episode 431: total reward = 142.0
# Episode 432: total reward = 126.0
# Episode 433: total reward = 125.0
# Episode 434: total reward = 132.0
# Episode 435: total reward = 126.0
# Episode 436: total reward = 129.0
# Episode 437: total reward = 130.0
# Episode 438: total reward = 124.0
# Episode 439: total reward = 131.0
# Episode 440: total reward = 133.0
# Episode 441: total reward = 176.0
# Episode 442: total reward = 134.0
# Episode 443: total reward = 146.0
# Episode 444: total reward = 143.0
# Episode 445: total reward = 14.0
# Episode 446: total reward = 145.0
# Episode 447: total reward = 139.0
# Episode 448: total reward = 142.0
# Episode 449: total reward = 126.0
# Episode 450: total reward = 137.0
# Episode 451: total reward = 138.0
# Episode 452: total reward = 140.0
# Episode 453: total reward = 157.0
# Episode 454: total reward = 146.0
# Episode 455: total reward = 145.0
# Episode 456: total reward = 147.0
# Episode 457: total reward = 148.0
# Episode 458: total reward = 138.0
# Episode 459: total reward = 144.0
# Episode 460: total reward = 143.0
# Episode 461: total reward = 142.0
# Episode 462: total reward = 133.0
# Episode 463: total reward = 127.0
# Episode 464: total reward = 135.0
# Episode 465: total reward = 132.0
# Episode 466: total reward = 140.0
# Episode 467: total reward = 132.0
# Episode 468: total reward = 132.0
# Episode 469: total reward = 130.0
# Episode 470: total reward = 140.0
# Episode 471: total reward = 137.0
# Episode 472: total reward = 145.0
# Episode 473: total reward = 146.0
# Episode 474: total reward = 132.0
# Episode 475: total reward = 149.0
# Episode 476: total reward = 135.0
# Episode 477: total reward = 143.0
# Episode 478: total reward = 137.0
# Episode 479: total reward = 136.0
# Episode 480: total reward = 144.0
# Episode 481: total reward = 146.0
# Episode 482: total reward = 148.0
# Episode 483: total reward = 144.0
# Episode 484: total reward = 141.0
# Episode 485: total reward = 148.0
# Episode 486: total reward = 145.0
# Episode 487: total reward = 140.0
# Episode 488: total reward = 144.0
# Episode 489: total reward = 150.0
# Episode 490: total reward = 157.0
# Episode 491: total reward = 140.0
# Episode 492: total reward = 132.0
# Episode 493: total reward = 137.0
# Episode 494: total reward = 138.0
# Episode 495: total reward = 131.0
# Episode 496: total reward = 134.0
# Episode 497: total reward = 136.0
# Episode 498: total reward = 135.0
# Episode 499: total reward = 148.0
# 動画保存完了：cartpole.mp4
